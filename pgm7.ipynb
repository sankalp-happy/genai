# %%
from transformers import pipeline
summarization = pipeline("summarization",model="facebook/bart-large-cnn")
text = """The BART model is a powerful sequence-to-sequence model that has been pre-trained on a large corpus of text data. 
It is designed to perform various natural language processing tasks, including text summarization, translation, and question answering. 
The BART model uses a combination of bidirectional and autoregressive transformers to generate high-quality summaries and translations. 
It has been shown to achieve state-of-the-art performance on several benchmark datasets, making it a popular choice for researchers and practitioners in the field of natural language processing."""
summary = summarization(text, max_length=50, min_length=25, do_sample=False)
print(summary[0]['summary_text'])
# Out:
# The BART model is a powerful sequence-to-sequence model that has been pre-trained on a large corpus of text data. It is designed to perform various natural language processing tasks, including text summarization, translation, and question answering

# %%
from transformers import pipeline
summarization = pipeline("summarization",model="facebook/bart-large-cnn")
text="abd.txt"
def split_text(text,max_length=800):
    return [text[i:i+max_length] for i in range(0, len(text), max_length)]
chunks = split_text(text)
final_summary = ""
for chunk in chunks:
    summary = summarization(chunk, max_length=50, min_length=20, do_sample=False)
    final_summary += summary[0]['summary_text'] + " "
print(final_summary.strip())
# Out:
# Your max_length is set to 50, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# C:\Program Files (x86) x86_64. abd. c:\ProgramFiles (x64)x86 64. cmap. cmp. cip. cv. cpp. cp
