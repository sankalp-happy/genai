# %%
# !pip uninstall -y transformers
# !pip install transformers==4.40.0

# %%
from transformers import pipeline
sentiment_analysis = pipeline("sentiment-analysis")
text="I am very happy today!"
result = sentiment_analysis(text,truncation=True)
print("sentiment:",result[0]['label'])
print("confidence:",result[0]['score'])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# c:\Users\pravi\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# sentiment: POSITIVE
# confidence: 0.9998517036437988
